# %% [markdown]
# # Data Preprocessing: Create DB and Load CSV into SQLite

# %%
import sqlite3
import pandas as pd
import os

# Read CSV
csv_file = 'grocery_inventory.csv'
df = pd.read_csv(csv_file)
df.head()
# Out:
#       Product_Name             Category Supplier_Name  Stock_Quantity  \
# 0      Bell Pepper  Fruits & Vegetables        Eimbee           867.0
# 1    Vegetable Oil          Oils & Fats      Digitube           335.0
# 2  Parmesan Cheese                Dairy        BlogXS           593.0
# 3           Carrot  Fruits & Vegetables        Avaveo           443.0
# 4           Garlic  Fruits & Vegetables          Katz           179.0
#
#   Unit_Price
# 0     $4.60
# 1     $2.00
# 2    $12.00
# 3     $1.50
# 4     $7.00

# %%
# Create SQLite DB and books table
db_path = os.path.join('..', 'database', 'grocery.db')
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

cursor.execute("""
DROP TABLE IF EXISTS grocery;
""")

cursor.execute("""
    CREATE TABLE IF NOT EXISTS grocery (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    product_name TEXT NOT NULL,
    category TEXT NOT NULL,
    supplier_name TEXT NOT NULL,
    Stock_quantity	INT,                       
    unit_price FLOAT NOT NULL
)
""")
conn.commit()

# %%
# Insert data into grocery table
df.to_sql('grocery', conn, if_exists='append', index=False)
print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
cursor.execute("SELECT * FROM grocery").fetchall()
# Out:
# [(1, 'Bell Pepper', 'Fruits & Vegetables', 'Eimbee', 867, '$4.60 '),
#  (2, 'Vegetable Oil', 'Oils & Fats', 'Digitube', 335, '$2.00 '),
#  (3, 'Parmesan Cheese', 'Dairy', 'BlogXS', 593, '$12.00 '),
#  (4, 'Carrot', 'Fruits & Vegetables', 'Avaveo', 443, '$1.50 '),
#  (5, 'Garlic', 'Fruits & Vegetables', 'Katz', 179, '$7.00 '),
#  (6, 'Lemon', 'Fruits & Vegetables', 'Yata', 602, '$2.40 '),
#  (7, 'Coconut Sugar', 'Grains & Pulses', 'Lazz', 228, '$5.00 '),
#  (8, 'Anchovies', 'Seafood', 'Zoonder', 816, '$10.00 '),
#  (9, 'Cheese', 'Dairy', 'Oozz', 514, '$9.00 '),
#  (10, 'Yogurt', 'Dairy', 'Jaxnation', 608, '$1.70 '),
#  (11, 'Cheddar Cheese', 'Dairy', 'Gabcube', 585, '$9.00 '),
#  (12, 'Avocado Oil', 'Oils & Fats', 'Dabtype', 280, '$10.00 '),
#  (13, 'Orange', 'Fruits & Vegetables', 'Flashdog', 735, '$2.90 '),
#  (14, 'Digestive Biscuit', 'Bakery', 'Devshare', 577, '$4.00 '),
#  (15, 'Cauliflower', 'Fruits & Vegetables', 'Cogilith', 909, '$2.50 '),
#  (16, 'Pear', 'Fruits & Vegetables', 'Roodel', 537, '$4.50 '),
#  (17, 'Egg (Turkey)', 'Dairy', 'Bluezoom', 540, '$2.50 '),
#  (18, 'Ricotta Cheese', 'Dairy', 'Skimia', 604, '$6.20 '),
#  (19, 'Eggplant', 'Fruits & Vegetables', 'Blogpad', 567, '$3.00 '),
#  (20, 'Whole Wheat Flour', 'Grains & Pulses', 'Dabjam', 472, '$2.70 '),
#  (21, 'Arabica Coffee', 'Beverages', 'Feedmix', 854, '$20.00 '),
#  (22, 'Sweet Potato', 'Fruits & Vegetables', 'Trupe', 433, '$2.00 '),
#  (23, 'Mango', 'Fruits & Vegetables', 'Meevee', 725, '$4.80 '),
#  (24, 'Kale', 'Fruits & Vegetables', 'Blogpad', 324, '$4.00 '),
#  (25, 'Jasmine Rice', 'Grains & Pulses', 'Topicware', 620, '$4.75 '),
#  (26, 'Sourdough Bread', 'Bakery', 'Plajo', 480, '$4.00 '),
#  (27, 'Green Coffee', 'Beverages', 'Skyndu', 407, '$12.00 '),
#  (28, 'Tilapia', 'Seafood', 'Vinder', 656, '$7.00 '),
#  (29, 'Arborio Rice', 'Grains & Pulses', 'Geba', 342, '$4.50 '),
#  (30, 'Bread Flour', 'Grains & Pulses', 'Dazzlesphere', 1120, '$1.50 '),
#  (31, 'Cucumber', 'Fruits & Vegetables', 'Kanoodle', 476, '$1.80 '),
#  (32, 'Milk', 'Dairy', 'Centimia', 160, '$0.90 '),
#  (33, 'Lime', 'Fruits & Vegetables', 'Livefish', 308, '$2.00 '),
#  (34, 'Rice Flour', 'Grains & Pulses', 'Quatz', 288, '$2.00 '),
#  (35, 'Sour Cream', 'Dairy', 'Skyvu', 278, '$4.00 '),
#  (36, 'Whole Wheat Bread', 'Bakery', 'Lazz', 202, '$3.50 '),
#  (37, 'Robusta Coffee', 'Beverages', 'Devpulse', 398, '$10.00 '),
#  (38, 'Chocolate Biscuit', 'Bakery', 'Yodo', 562, '$5.00 '),
#  (39, 'Palm Oil', 'Oils & Fats', 'Skipstorm', 430, '$1.80 '),
#  (40, 'Sesame Oil', 'Oils & Fats', 'Dabtype', 723, '$6.50 '),
#  (41, 'Lettuce', 'Fruits & Vegetables', 'Fadeo', 268, '$2.00 '),
#  (42, 'Feta Cheese', 'Dairy', 'Rhynyx', 534, '$7.00 '),
#  (43, 'Apricot', 'Fruits & Vegetables', 'Skinix', 477, '$5.00 '),
#  (44, 'Peanut Oil', 'Oils & Fats', 'Tagopia', 413, '$4.00 '),
#  (45, 'Olive Oil', 'Oils & Fats', 'Realmix', 346, '$6.00 '),
#  (46, 'Egg (Duck)', 'Dairy', 'Katz', 450, '$1.00 '),
#  (47, 'Pineapple', 'Fruits & Vegetables', 'Brainverse', 420, '$3.50 '),
#  (48, 'Trout', 'Seafood', 'Blogtag', 517, '$12.00 '),
#  (49, 'Onion', 'Fruits & Vegetables', 'Oba', 543, '$2.00 '),
#  (50, 'Cream', 'Dairy', 'Oyondu', 304, '$2.50 '),
#  (51, 'Sardines', 'Seafood', 'Eayo', 371, '$6.00 '),
#  (52, 'Plum', 'Fruits & Vegetables', 'Topicstorm', 411, '$4.00 '),
#  (53, 'Sushi Rice', 'Grains & Pulses', 'Katz', 470, '$4.25 '),
#  (54, 'Black Rice', 'Grains & Pulses', 'Vinder', 680, '$6.00 '),
#  (55, 'Wild Rice', 'Grains & Pulses', 'Wordpedia', 392, '$10.00 '),
#  (56, 'Pomegranate', 'Fruits & Vegetables', 'Meeveo', 766, '$6.00 '),
#  (57, 'Cabbage', 'Fruits & Vegetables', 'Lajo', 522, '$0.90 '),
#  (58, 'All-Purpose Flour', 'Grains & Pulses', 'Dabjam', None, '$1.75 '),
#  (59, 'Whipped Cream', 'Dairy', 'Yakitri', 364, '$4.00 '),
#  (60, 'Grapes', 'Fruits & Vegetables', 'Thoughtmix', 820, '$5.50 '),
#  (61, 'Sunflower Oil', 'Oils & Fats', 'Photofeed', 341, '$2.50 '),
#  (62, 'Short Grain Rice', 'Grains & Pulses', 'Katz', 314, '$4.50 '),
#  (63, 'Tuna', 'Seafood', 'Meemm', 602, '$18.00 '),
#  (64, 'Banana', 'Fruits & Vegetables', 'Youfeed', 272, '$53.82 '),
#  (65, 'Coconut', 'Fruits & Vegetables', 'Katz', 396, '$5.00 '),
#  (66, 'Almond Flour', 'Grains & Pulses', 'Trudoo', 582, '$9.50 '),
#  (67, 'Greek Yogurt', 'Dairy', 'Thoughtstorm', 398, '$3.00 '),
#  (68, 'Peach', 'Fruits & Vegetables', 'Youfeed', 438, '$4.00 '),
#  (69, 'Asparagus', 'Fruits & Vegetables', 'Yabox', 438, '$5.00 '),
#  (70, 'Mushrooms', 'Fruits & Vegetables', 'Yakijo', 441, '$6.00 '),
#  (71, 'Black Tea', 'Beverages', 'Kare', 278, '$4.70 '),
#  (72, 'White Tea', 'Beverages', 'Brightbean', 592, '$25.00 '),
#  (73, 'White Rice', 'Grains & Pulses', 'Tagcat', 172, '$1.80 '),
#  (74, 'Long Grain Rice', 'Grains & Pulses', 'Flashspan', 455, '$1.50 '),
#  (75, 'Rye Bread', 'Bakery', 'Brainlounge', 431, '$3.00 '),
#  (76, 'Egg (Goose)', 'Dairy', 'Gabvine', 748, '$2.50 '),
#  (77, 'Brown Rice', 'Grains & Pulses', 'Viva', 440, '$2.50 '),
#  (78, 'Black Coffee', 'Beverages', 'Skyndu', 517, '$15.00 '),
#  (79, 'White Sugar', 'Grains & Pulses', 'Dazzlesphere', 429, '$2.00 '),
#  (80, 'Egg (Quail)', 'Dairy', 'Realpoint', 425, '$0.80 '),
#  (81, 'Herbal Tea', 'Beverages', 'Pixonyx', 292, '$30.00 '),
#  (82, 'Coconut Oil', 'Oils & Fats', 'Gevee', 266, '$5.00 '),
#  (83, 'Buttermilk', 'Dairy', 'Zoombox', 365, '$2.45 '),
#  (84, 'Evaporated Milk', 'Dairy', 'Demivee', 342, '$2.00 '),
#  (85, 'Powdered Sugar', 'Grains & Pulses', 'Devbug', 491, '$2.50 '),
#  (86, 'Cod', 'Seafood', 'Kwimbee', 359, '$8.00 '),
#  (87, 'Kiwi', 'Fruits & Vegetables', 'Zooveo', 258, '$6.00 '),
#  (88, 'Haddock', 'Seafood', 'Kwimbee', 799, '$9.00 '),
#  (89, 'Tomato', 'Fruits & Vegetables', 'Demimbu', 271, '$2.50 '),
#  (90, 'Gouda Cheese', 'Dairy', 'Kamba', 492, '$7.00 '),
#  (91, 'Spinach', 'Fruits & Vegetables', 'Shuffledrive', 330, '$2.50 '),
#  (92, 'Canola Oil', 'Oils & Fats', 'Thoughtmix', 575, '$2.30 '),
#  (93, 'Basmati Rice', 'Grains & Pulses', 'Kanoodle', 234, '$4.50 '),
#  (94, 'Oatmeal Biscuit', 'Bakery', 'Kwimbee', 294, '$5.00 '),
#  (95, 'Green Beans', 'Fruits & Vegetables', 'Viva', 415, '$2.00 '),
#  (96, 'Apple', 'Fruits & Vegetables', 'Jabbersphere', 417, '$3.50 '),
#  (97, 'Peas', 'Fruits & Vegetables', 'Youbridge', 383, '$3.00 '),
#  (98, 'Cottage Cheese', 'Dairy', 'Feedmix', 261, '$4.80 '),
#  (99, 'Multigrain Bread', 'Bakery', 'Topicware', 517, '$3.20 '),
#  (100, 'Potato', 'Fruits & Vegetables', 'Thoughtbridge', 194, '$1.20 '),
#  (101, 'Halibut', 'Seafood', 'Wikibox', 392, '$20.00 '),
#  (102, 'Salmon', 'Seafood', 'Kamba', 605, '$15.00 '),
#  (103, 'Broccoli', 'Fruits & Vegetables', 'Abatz', 604, '$4.00 '),
#  (104, 'Corn Oil', 'Oils & Fats', 'Tagopia', 414, '$2.50 '),
#  (105, 'Strawberries', 'Fruits & Vegetables', 'Meevee', 279, '$5.90 '),
#  (106, 'Green Tea', 'Beverages', 'Photobug', 484, '$8.00 '),
#  (107, 'Swiss Cheese', 'Dairy', 'Reallinks', 636, '$8.00 '),
#  (108, 'Cherry', 'Fruits & Vegetables', 'Jabbersphere', 159, '$8.00 '),
#  (109, 'Zucchini', 'Fruits & Vegetables', 'Quimm', 563, '$2.50 '),
#  (110, 'Butter Biscuit', 'Bakery', 'Ozu', 263, '$6.00 '),
#  (111, 'Egg (Chicken)', 'Dairy', 'Einti', 306, '$0.20 '),
#  (112, 'White Bread', 'Bakery', 'Tagfeed', 586, '$2.50 '),
#  (113, 'Watermelon', 'Fruits & Vegetables', 'Latz', 461, '$3.00 '),
#  (114, 'Vanilla Biscuit', 'Bakery', 'Ozu', 263, '$5.50 '),
#  (115, 'Papaya', 'Fruits & Vegetables', 'Twitterwire', 429, '$4.50 '),
#  (116, 'Butter', 'Dairy', 'Meembee', 241, '$3.10 '),
#  (117, 'Heavy Cream', 'Dairy', 'Ntags', 546, '$4.00 '),
#  (118, 'Blueberries', 'Fruits & Vegetables', 'Flipbug', 428, '$10.00 '),
#  (119, 'Mozzarella Cheese', 'Dairy', 'Devpoint', 330, '$7.20 '),
#  (120, 'Mackerel', 'Seafood', 'Dabfeed', 484, '$7.50 '),
#  (121, 'Raw Sugar', 'Grains & Pulses', 'Cogilith', 312, '$1.50 ')]

# %%
conn.commit()
conn.close()
